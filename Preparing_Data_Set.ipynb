# %%
import os
import numpy as np
import pandas as pd
from IPython.display import display
from matplotlib import pyplot as plt
# %matplotlib inline
import time

# Pylians, to calculate power spectrum
import MAS_library as MASL
import Pk_library as PKL

# Brenda lib
from brenda_lib import cySim_lib as cysim
from brenda_lib import pySim_lib as pysim

# %%
# Simulation basic settings
h = 0.67
Ngrid = 32
Npart = Ngrid ** 3
lbox = 200  # 502.5/h #502.5/h #128/h

# %%
# Define base path
base_path = '/home/msoumad/Git/Aletheia-ML_HF/L200-N32'
snapshot_base_dir = os.path.join(base_path, 'Snapshots')
rockstar_base_dir = os.path.join(base_path, 'Rockstar_Outputs')
output_base_dir = os.path.join(base_path, 'Data_Set')

# %%
# Define the columns to be read for the Rockstar output
columns = [
    'Particle_ID', 'Px', 'Py', 'Pz', 'PVx', 'PVy', 'PVz',
    'Halo_ID', 'HaloType', 'Hx', 'Hy', 'Hz', 'HVx', 'HVy', 'HVz'
]

# %%
def read_gadget_snapshot(snapshot_file):
    # Read snapshot
    header = pysim.read_header_gadget4(fname=snapshot_file)
    gadget4 = pysim.read_dark_matter_gadget4(fname=snapshot_file)

    # Convert to DataFrame
    snapshot = {
        "Particle_ID": gadget4["ids"],
        "Px": gadget4["pos"][:, 0] / h,
        "Py": gadget4["pos"][:, 1] / h,
        "Pz": gadget4["pos"][:, 2] / h,
        "PVx": gadget4["vel"][:, 0],
        "PVy": gadget4["vel"][:, 1],
        "PVz": gadget4["vel"][:, 2],
    }
    snapshot_df = pd.DataFrame(snapshot)
    snapshot_df.set_index("Particle_ID", inplace=True)
    snapshot_df.sort_index(ascending=True, inplace=True)
    return snapshot_df

# %%
def read_rockstar_data(rockstar_file):
    rockstar_df = pd.read_csv(rockstar_file, sep='\s+', low_memory=False, names=columns, skiprows=1)
    rockstar_df['Particle_ID'] = rockstar_df['Particle_ID'].astype(int)
    rockstar_df.set_index('Particle_ID', inplace=True)
    return rockstar_df

# %%
def combine_dataframes(snapshot_df, rockstar_df):
    combined_df = snapshot_df.merge(rockstar_df, left_index=True, right_index=True, how='left', suffixes=('', '_halo'))
    combined_df['Host'] = combined_df['Halo_ID'].apply(lambda x: 'yes' if pd.notna(x) else 'no')
    combined_df = combined_df.reset_index()[[
        'Particle_ID', 'Px', 'Py', 'Pz', 'PVx', 'PVy', 'PVz',
        'Host', 'Halo_ID', 'HaloType', 'Hx', 'Hy', 'Hz', 'HVx', 'HVy', 'HVz'
    ]]
    return combined_df

# %%
def create_directories(base_dir):
    for subdir in ['Training_Set', 'Testing_Set']:
        for fmt in ['Ascii', 'Bin']:
            os.makedirs(os.path.join(base_dir, subdir, fmt), exist_ok=True)

# %%
def process_files(snapshot_file, rockstar_file, output_ascii, output_bin):
    print(f"Processing the file {os.path.basename(snapshot_file)}...")

    snapshot_df = read_gadget_snapshot(snapshot_file)
    rockstar_df = read_rockstar_data(rockstar_file)
    combined_df = combine_dataframes(snapshot_df, rockstar_df)

    # Save as ASCII
    combined_df.to_csv(output_ascii, sep=' ', index=False, na_rep='NaN')

    # Save as binary
    combined_df.to_pickle(output_bin)

    print(f"File {os.path.basename(snapshot_file)} has been processed.")

# %%
def execute():
    create_directories(output_base_dir)

    start_time = time.time()

    for i in range(150):
        folder_name = f'output_run{i:04d}'
        snapshot_file = os.path.join(snapshot_base_dir, folder_name, 'snapshot_000')
        rockstar_file = os.path.join(rockstar_base_dir, folder_name, 'Halo_Details.ascii')

        if i < 100:
            output_ascii = os.path.join(output_base_dir, 'Training_Set', 'Ascii', f'{i:04d}.ascii')
            output_bin = os.path.join(output_base_dir, 'Training_Set', 'Bin', f'{i:04d}.bin')
        else:
            output_ascii = os.path.join(output_base_dir, 'Testing_Set', 'Ascii', f'{i:04d}.ascii')
            output_bin = os.path.join(output_base_dir, 'Testing_Set', 'Bin', f'{i:04d}.bin')

        print(f"File processing started for {i:04d}")
        process_files(snapshot_file, rockstar_file, output_ascii, output_bin)
        print(f"File processing completed for {i:04d}")

    end_time = time.time()
    print(f"Data set preparation completed in {end_time - start_time:.2f} seconds.")
    
execute()
# Out:
# File processing started for 0000
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0000
# File processing started for 0001
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0001
# File processing started for 0002
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0002
# File processing started for 0003
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0003
# File processing started for 0004
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0004
# File processing started for 0005
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0005
# File processing started for 0006
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0006
# File processing started for 0007
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0007
# File processing started for 0008
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0008
# File processing started for 0009
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0009
# File processing started for 0010
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0010
# File processing started for 0011
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0011
# File processing started for 0012
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0012
# File processing started for 0013
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0013
# File processing started for 0014
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0014
# File processing started for 0015
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0015
# File processing started for 0016
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0016
# File processing started for 0017
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0017
# File processing started for 0018
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0018
# File processing started for 0019
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0019
# File processing started for 0020
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0020
# File processing started for 0021
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0021
# File processing started for 0022
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0022
# File processing started for 0023
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0023
# File processing started for 0024
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0024
# File processing started for 0025
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0025
# File processing started for 0026
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0026
# File processing started for 0027
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0027
# File processing started for 0028
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0028
# File processing started for 0029
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0029
# File processing started for 0030
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0030
# File processing started for 0031
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0031
# File processing started for 0032
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0032
# File processing started for 0033
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0033
# File processing started for 0034
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0034
# File processing started for 0035
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0035
# File processing started for 0036
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0036
# File processing started for 0037
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0037
# File processing started for 0038
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0038
# File processing started for 0039
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0039
# File processing started for 0040
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0040
# File processing started for 0041
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0041
# File processing started for 0042
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0042
# File processing started for 0043
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0043
# File processing started for 0044
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0044
# File processing started for 0045
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0045
# File processing started for 0046
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0046
# File processing started for 0047
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0047
# File processing started for 0048
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0048
# File processing started for 0049
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0049
# File processing started for 0050
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0050
# File processing started for 0051
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0051
# File processing started for 0052
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0052
# File processing started for 0053
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0053
# File processing started for 0054
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0054
# File processing started for 0055
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0055
# File processing started for 0056
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0056
# File processing started for 0057
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0057
# File processing started for 0058
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0058
# File processing started for 0059
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0059
# File processing started for 0060
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0060
# File processing started for 0061
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0061
# File processing started for 0062
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0062
# File processing started for 0063
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0063
# File processing started for 0064
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0064
# File processing started for 0065
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0065
# File processing started for 0066
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0066
# File processing started for 0067
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0067
# File processing started for 0068
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0068
# File processing started for 0069
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0069
# File processing started for 0070
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0070
# File processing started for 0071
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0071
# File processing started for 0072
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0072
# File processing started for 0073
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0073
# File processing started for 0074
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0074
# File processing started for 0075
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0075
# File processing started for 0076
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0076
# File processing started for 0077
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0077
# File processing started for 0078
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0078
# File processing started for 0079
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0079
# File processing started for 0080
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0080
# File processing started for 0081
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0081
# File processing started for 0082
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0082
# File processing started for 0083
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0083
# File processing started for 0084
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0084
# File processing started for 0085
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0085
# File processing started for 0086
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0086
# File processing started for 0087
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0087
# File processing started for 0088
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0088
# File processing started for 0089
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0089
# File processing started for 0090
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0090
# File processing started for 0091
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0091
# File processing started for 0092
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0092
# File processing started for 0093
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0093
# File processing started for 0094
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0094
# File processing started for 0095
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0095
# File processing started for 0096
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0096
# File processing started for 0097
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0097
# File processing started for 0098
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0098
# File processing started for 0099
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0099
# File processing started for 0100
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0100
# File processing started for 0101
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0101
# File processing started for 0102
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0102
# File processing started for 0103
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0103
# File processing started for 0104
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0104
# File processing started for 0105
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0105
# File processing started for 0106
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0106
# File processing started for 0107
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0107
# File processing started for 0108
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0108
# File processing started for 0109
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0109
# File processing started for 0110
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0110
# File processing started for 0111
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0111
# File processing started for 0112
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0112
# File processing started for 0113
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0113
# File processing started for 0114
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0114
# File processing started for 0115
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0115
# File processing started for 0116
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0116
# File processing started for 0117
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0117
# File processing started for 0118
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0118
# File processing started for 0119
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0119
# File processing started for 0120
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0120
# File processing started for 0121
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0121
# File processing started for 0122
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0122
# File processing started for 0123
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0123
# File processing started for 0124
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0124
# File processing started for 0125
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0125
# File processing started for 0126
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0126
# File processing started for 0127
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0127
# File processing started for 0128
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0128
# File processing started for 0129
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0129
# File processing started for 0130
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0130
# File processing started for 0131
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0131
# File processing started for 0132
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0132
# File processing started for 0133
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0133
# File processing started for 0134
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0134
# File processing started for 0135
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0135
# File processing started for 0136
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0136
# File processing started for 0137
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0137
# File processing started for 0138
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0138
# File processing started for 0139
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0139
# File processing started for 0140
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0140
# File processing started for 0141
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0141
# File processing started for 0142
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0142
# File processing started for 0143
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0143
# File processing started for 0144
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0144
# File processing started for 0145
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0145
# File processing started for 0146
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0146
# File processing started for 0147
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0147
# File processing started for 0148
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0148
# File processing started for 0149
# Processing the file snapshot_000...
# Allocating memory for 32768 particles 0.375Mb
# Read data in file #0 for 32768/32768 particles...
# File snapshot_000 has been processed.
# File processing completed for 0149
# Data set preparation completed in 19.43 seconds.
