# %%
import os
import numpy as np
import pandas as pd
from IPython.display import display
from matplotlib import pyplot as plt
# %matplotlib inline
import time

# Pylians, to calculate power spectrum
import MAS_library as MASL
import Pk_library as PKL

# Brenda lib
from brenda_lib import cySim_lib as cysim
from brenda_lib import pySim_lib as pysim

# %%
# Simulation basic settings
h = 0.67
Ngrid = 128
Npart = Ngrid ** 3
lbox = 400  # 502.5/h #502.5/h #128/h

# %%
# Columns of Gadget Snapshots
col_names = ['id', 'X', 'Y', 'Z', 'Vx', 'Vy', 'Vz']

# Define the columns to be read for the Rockstar output
Columns_Halos = ['Particle_ID', 'Px', 'Py', 'Pz', 'PVx', 'PVy', 'PVz', 'Halo_ID', 'HaloType', 'Hx', 'Hy', 'Hz', 'HVx', 'HVy', 'HVz']

# %%
# Base paths of the Gadget snapshots and Rockstar output
base_path = '/home/msoumad/Git/L400-N128/'
snapshot_base_path = os.path.join(base_path, 'SnapShots/output_run')
rockstar_base_path = os.path.join(base_path, 'Rockstar_Output/output_run')

# %%
# Output directory setup
# Inside Data_Set we will have Training_Set and Testing_Set
data_set_path = os.path.join(base_path, 'Data_Set')
training_set_path = os.path.join(data_set_path, 'Training_Set')
testing_set_path = os.path.join(data_set_path, 'Testing_Set')

# Creating sub directory
for dir_path in [training_set_path, testing_set_path]:
    for sub_dir in ['Bin', 'Ascii']:
        os.makedirs(os.path.join(dir_path, sub_dir), exist_ok=True)

# %%
# Code to read, process and save the snapshot and rockstar data
def process_and_save(snapshot_path, halo_path, output_dir, index):
    # Read the snapshot data
    header = pysim.read_header_gadget4(fname=snapshot_path)
    gadget4 = pysim.read_dark_matter_gadget4(fname=snapshot_path)

    # Create snapshot DataFrame
    snapshot = {
        "Particle_ID": gadget4["ids"],
        "Px": gadget4["pos"][:, 0] / h,
        "Py": gadget4["pos"][:, 1] / h,
        "Pz": gadget4["pos"][:, 2] / h,
        "PVx": gadget4["vel"][:, 0],
        "PVy": gadget4["vel"][:, 1],
        "PVz": gadget4["vel"][:, 2],
    }
    snapshot = pd.DataFrame(snapshot)
    snapshot.set_index("Particle_ID", inplace=True)
    snapshot.sort_index(ascending=True, inplace=True)

    # Read the Rockstar halo data
    halos_data = pd.read_csv(halo_path, sep='\s+', low_memory=False, names=Columns_Halos, skiprows=1)
    df_halos = pd.DataFrame(halos_data, columns=Columns_Halos)
    df_halos['Particle_ID'] = df_halos['Particle_ID'].astype(int)
    df_halos.set_index('Particle_ID', inplace=True)

    # Merge the DataFrames
    combined_df = snapshot.merge(df_halos, left_index=True, right_index=True, how='left', suffixes=('', '_halo'))
    combined_df['Host'] = combined_df['Halo_ID'].apply(lambda x: 'yes' if pd.notna(x) else 'no')
    combined_df = combined_df.reset_index()[[
        'Particle_ID', 'Px', 'Py', 'Pz', 'PVx', 'PVy', 'PVz',
        'Host', 'Halo_ID', 'HaloType', 'Hx', 'Hy', 'Hz', 'HVx', 'HVy', 'HVz'
    ]]

    # Formatted index for output file naming
    output_index = f'{index:04d}'

    # Save as ASCII
    ascii_path = os.path.join(output_dir, 'Ascii', f'output_{output_index}.ascii')
    combined_df.to_csv(ascii_path, sep=' ', index=False, na_rep='NaN')
    print(f"Data saved to {ascii_path}")

    # Save as Binary
    bin_path = os.path.join(output_dir, 'Bin', f'output_{output_index}.bin')
    combined_df.to_pickle(bin_path)
    print(f"Data saved to {bin_path}")

# %%
# Start calculating time
start_time = time.time()

# Initialize total size accumulator
total_size_mb = 0

# Processing files and saving their exact location
print(f"Processing the files...")
for i in range(150):
    run_str = f'{i:04d}'
    snapshot_file = os.path.join(snapshot_base_path + run_str, 'snapshot_000')
    halo_file = os.path.join(rockstar_base_path + run_str, 'Halo_Details.ascii')
    print(f"Working on file {run_str}...")
    
    if i < 100:
        output_dir = training_set_path
    else:
        output_dir = testing_set_path

    process_and_save(snapshot_file, halo_file, output_dir, i)

    # Calculate file sizes in MB
    ascii_path = os.path.join(output_dir, 'Ascii', f'output_{run_str}.ascii')
    bin_path = os.path.join(output_dir, 'Bin', f'output_{run_str}.bin')

    # Accumulate total size
    total_size_mb += (os.path.getsize(ascii_path) + os.path.getsize(bin_path)) / (1024 * 1024)  # Convert bytes to MB
    
# End time
end_time = time.time()
elapsed_time = end_time - start_time
print(f"File processing finished!.")
# Print total size of all files
print(f"Total size of all output files: {total_size_mb:.2f} MB")
print(f"Total execution time: {elapsed_time:.2f} seconds")
# Out:
# Processing the files...
# Working on file 0000...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0000.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0000.bin
# Working on file 0001...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0001.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0001.bin
# Working on file 0002...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0002.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0002.bin
# Working on file 0003...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0003.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0003.bin
# Working on file 0004...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0004.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0004.bin
# Working on file 0005...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0005.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0005.bin
# Working on file 0006...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0006.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0006.bin
# Working on file 0007...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0007.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0007.bin
# Working on file 0008...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0008.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0008.bin
# Working on file 0009...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0009.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0009.bin
# Working on file 0010...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0010.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0010.bin
# Working on file 0011...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0011.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0011.bin
# Working on file 0012...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0012.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0012.bin
# Working on file 0013...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0013.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0013.bin
# Working on file 0014...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0014.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0014.bin
# Working on file 0015...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0015.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0015.bin
# Working on file 0016...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0016.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0016.bin
# Working on file 0017...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0017.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0017.bin
# Working on file 0018...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0018.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0018.bin
# Working on file 0019...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0019.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0019.bin
# Working on file 0020...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0020.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0020.bin
# Working on file 0021...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0021.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0021.bin
# Working on file 0022...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0022.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0022.bin
# Working on file 0023...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0023.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0023.bin
# Working on file 0024...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0024.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0024.bin
# Working on file 0025...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0025.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0025.bin
# Working on file 0026...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0026.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0026.bin
# Working on file 0027...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0027.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0027.bin
# Working on file 0028...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0028.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0028.bin
# Working on file 0029...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0029.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0029.bin
# Working on file 0030...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0030.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0030.bin
# Working on file 0031...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0031.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0031.bin
# Working on file 0032...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0032.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0032.bin
# Working on file 0033...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0033.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0033.bin
# Working on file 0034...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0034.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0034.bin
# Working on file 0035...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0035.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0035.bin
# Working on file 0036...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0036.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0036.bin
# Working on file 0037...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0037.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0037.bin
# Working on file 0038...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0038.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0038.bin
# Working on file 0039...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0039.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0039.bin
# Working on file 0040...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0040.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0040.bin
# Working on file 0041...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0041.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0041.bin
# Working on file 0042...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0042.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0042.bin
# Working on file 0043...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0043.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0043.bin
# Working on file 0044...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0044.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0044.bin
# Working on file 0045...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0045.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0045.bin
# Working on file 0046...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0046.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0046.bin
# Working on file 0047...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0047.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0047.bin
# Working on file 0048...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0048.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0048.bin
# Working on file 0049...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0049.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0049.bin
# Working on file 0050...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0050.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0050.bin
# Working on file 0051...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0051.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0051.bin
# Working on file 0052...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0052.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0052.bin
# Working on file 0053...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0053.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0053.bin
# Working on file 0054...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0054.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0054.bin
# Working on file 0055...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0055.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0055.bin
# Working on file 0056...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0056.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0056.bin
# Working on file 0057...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0057.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0057.bin
# Working on file 0058...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0058.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0058.bin
# Working on file 0059...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0059.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0059.bin
# Working on file 0060...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0060.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0060.bin
# Working on file 0061...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0061.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0061.bin
# Working on file 0062...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0062.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0062.bin
# Working on file 0063...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0063.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0063.bin
# Working on file 0064...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0064.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0064.bin
# Working on file 0065...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0065.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0065.bin
# Working on file 0066...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0066.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0066.bin
# Working on file 0067...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0067.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0067.bin
# Working on file 0068...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0068.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0068.bin
# Working on file 0069...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0069.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0069.bin
# Working on file 0070...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0070.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0070.bin
# Working on file 0071...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0071.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0071.bin
# Working on file 0072...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0072.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0072.bin
# Working on file 0073...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0073.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0073.bin
# Working on file 0074...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0074.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0074.bin
# Working on file 0075...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0075.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0075.bin
# Working on file 0076...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0076.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0076.bin
# Working on file 0077...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0077.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0077.bin
# Working on file 0078...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0078.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0078.bin
# Working on file 0079...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0079.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0079.bin
# Working on file 0080...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0080.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0080.bin
# Working on file 0081...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0081.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0081.bin
# Working on file 0082...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0082.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0082.bin
# Working on file 0083...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0083.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0083.bin
# Working on file 0084...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0084.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0084.bin
# Working on file 0085...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0085.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0085.bin
# Working on file 0086...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0086.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0086.bin
# Working on file 0087...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0087.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0087.bin
# Working on file 0088...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0088.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0088.bin
# Working on file 0089...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0089.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0089.bin
# Working on file 0090...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0090.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0090.bin
# Working on file 0091...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0091.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0091.bin
# Working on file 0092...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0092.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0092.bin
# Working on file 0093...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0093.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0093.bin
# Working on file 0094...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0094.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0094.bin
# Working on file 0095...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0095.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0095.bin
# Working on file 0096...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0096.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0096.bin
# Working on file 0097...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0097.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0097.bin
# Working on file 0098...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0098.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0098.bin
# Working on file 0099...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Ascii/output_0099.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Training_Set/Bin/output_0099.bin
# Working on file 0100...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0100.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0100.bin
# Working on file 0101...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0101.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0101.bin
# Working on file 0102...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0102.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0102.bin
# Working on file 0103...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0103.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0103.bin
# Working on file 0104...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0104.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0104.bin
# Working on file 0105...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0105.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0105.bin
# Working on file 0106...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0106.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0106.bin
# Working on file 0107...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0107.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0107.bin
# Working on file 0108...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0108.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0108.bin
# Working on file 0109...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0109.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0109.bin
# Working on file 0110...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0110.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0110.bin
# Working on file 0111...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0111.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0111.bin
# Working on file 0112...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0112.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0112.bin
# Working on file 0113...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0113.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0113.bin
# Working on file 0114...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0114.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0114.bin
# Working on file 0115...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0115.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0115.bin
# Working on file 0116...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0116.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0116.bin
# Working on file 0117...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0117.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0117.bin
# Working on file 0118...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0118.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0118.bin
# Working on file 0119...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0119.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0119.bin
# Working on file 0120...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0120.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0120.bin
# Working on file 0121...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0121.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0121.bin
# Working on file 0122...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0122.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0122.bin
# Working on file 0123...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0123.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0123.bin
# Working on file 0124...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0124.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0124.bin
# Working on file 0125...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0125.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0125.bin
# Working on file 0126...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0126.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0126.bin
# Working on file 0127...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0127.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0127.bin
# Working on file 0128...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0128.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0128.bin
# Working on file 0129...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0129.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0129.bin
# Working on file 0130...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0130.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0130.bin
# Working on file 0131...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0131.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0131.bin
# Working on file 0132...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0132.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0132.bin
# Working on file 0133...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0133.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0133.bin
# Working on file 0134...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0134.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0134.bin
# Working on file 0135...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0135.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0135.bin
# Working on file 0136...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0136.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0136.bin
# Working on file 0137...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0137.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0137.bin
# Working on file 0138...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0138.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0138.bin
# Working on file 0139...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0139.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0139.bin
# Working on file 0140...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0140.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0140.bin
# Working on file 0141...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0141.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0141.bin
# Working on file 0142...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0142.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0142.bin
# Working on file 0143...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0143.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0143.bin
# Working on file 0144...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0144.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0144.bin
# Working on file 0145...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0145.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0145.bin
# Working on file 0146...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0146.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0146.bin
# Working on file 0147...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0147.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0147.bin
# Working on file 0148...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0148.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0148.bin
# Working on file 0149...
# Allocating memory for 2097152 particles 24.0Mb
# Read data in file #0 for 2097152/2097152 particles...
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Ascii/output_0149.ascii
# Data saved to /home/msoumad/Git/L400-N128/Data_Set/Testing_Set/Bin/output_0149.bin
# File processing finished!.
# Total size of all output files: 64127.39 MB
# Total execution time: 1394.69 seconds
